# %% [markdown]
# ## Part 1 : Exploring Data Visualization in Python with Matplotlib

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df["species"] = iris.target

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %%
iris_df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
features = iris.feature_names

# %%
features
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
for feature in features:
    for species_id, species_name in enumerate(iris.target_names):
        subset = iris_df[iris_df["species"] == species_id]
        plt.plot(subset[feature], label=species_name)  
    plt.title(f"{feature} vs. Species")
    plt.xlabel("Index")
    plt.ylabel("Value")
    plt.legend(title="Species")
    plt.show()

# %%
sns.set(style="whitegrid")
sns.pairplot(iris_df, hue="species", palette="Set1")
plt.show()

# %%
for i in range(len(features) - 1):
    for j in range(i + 1, len(features)):
        feature_x = features[i]
        feature_y = features[j]        

        plt.figure(figsize=(8, 6))
        sns.scatterplot(data=iris_df, x=feature_x, y=feature_y, hue="species", palette="Set1")
        plt.title(f"{feature_x} vs {feature_y} by Species")
        plt.xlabel(feature_x)
        plt.ylabel(feature_y)
        plt.legend(title="Species")        
        plt.show()

# %%
for feature in features:  
    for species_id, species_name in enumerate(iris.target_names):
        subset = iris_df[iris_df["species"] == species_id]
        sns.histplot(subset[feature],bins =20, kde=True, label=species_name)
    plt.title(f"Distribution of {feature} by Species")
    plt.xlabel(feature)
    plt.ylabel("Value")
    plt.legend(title="Species")
    plt.show()

# %%
species_counts = iris_df["species"].value_counts()

# %%
species_counts
# Out:
# 0    50
# 1    50
# 2    50
# Name: species, dtype: int64

# %%
sns.barplot(x=species_counts.index, y=species_counts.values, palette="Set2")
plt.title("Species Count")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %%
correlation_matrix = iris_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Feature Correlation")
plt.show()

# %% [markdown]
# ## Bonus Question

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.violinplot(x="survived", y="age", hue="sex", data=titanic, split=True)
plt.title("Distribution of Age Among Titanic Passengers Based on Survival and Gender")
plt.show()

# %% [markdown]
# ## Part 2 : Handling Null Values in Python with Pandas

# %%
data = pd.read_csv("california_housing.csv")

# %%
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0       NaN   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0       NaN     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035        NaN       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
data.isnull().sum()
# Out:
# MedInc        1008
# HouseAge      1001
# AveRooms      1047
# AveBedrms     1042
# Population    1001
# AveOccup       986
# Latitude       997
# Longitude     1058
# dtype: int64

# %%
data.dropna().shape
# Out:
# (13767, 8)

# %%
data["AveOccup"].dropna().shape
# Out:
# (19654,)

# %%
data["AveOccup"].isnull().sum()
# Out:
# 986

# %%
data = data.dropna(subset = ["AveOccup"])

# %%
data.isnull().sum()
# Out:
# MedInc        963
# HouseAge      956
# AveRooms      992
# AveBedrms     992
# Population    954
# AveOccup        0
# Latitude      961
# Longitude     998
# dtype: int64

# %%
# "total_bedrooms" column is not in the dataset so i'm using "AveBedrms" column for filling the Null Values

# %%
data2 = data[["AveBedrms"]]

# %%
data2
# Out:
#        AveBedrms
# 0       1.023810
# 1       0.971880
# 2       1.073446
# 4       1.081081
# 5       1.103627
# ...          ...
# 20635   1.133333
# 20636        NaN
# 20637   1.120092
# 20638   1.171920
# 20639   1.162264
#
# [19654 rows x 1 columns]

# %%
data2.isnull().sum()
# Out:
# AveBedrms    992
# dtype: int64

# %%
#Replace the missing values in the "AveBedrms" column with the median value of the column.
data2["median_operation"] = data2["AveBedrms"].fillna(data2["AveBedrms"].median())
# Out:
# /var/folders/w8/9lh5cdc953qdl52569vcm35r0000gn/T/ipykernel_5037/4189484284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["median_operation"] = data2["AveBedrms"].fillna(data2["AveBedrms"].median())

# %%
data2
# Out:
#        AveBedrms  median_operation
# 0       1.023810          1.023810
# 1       0.971880          0.971880
# 2       1.073446          1.073446
# 4       1.081081          1.081081
# 5       1.103627          1.103627
# ...          ...               ...
# 20635   1.133333          1.133333
# 20636        NaN          1.048684
# 20637   1.120092          1.120092
# 20638   1.171920          1.171920
# 20639   1.162264          1.162264
#
# [19654 rows x 2 columns]

# %%
#Fill the missing values in the "AveBedrms" column using interpolation.
data2["interpolation_operation"] = data2["AveBedrms"].interpolate(method = "linear")
# Out:
# /var/folders/w8/9lh5cdc953qdl52569vcm35r0000gn/T/ipykernel_5037/2742973052.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["interpolation_operation"] = data2["AveBedrms"].interpolate(method = "linear")

# %%
data2
# Out:
#        AveBedrms  median_operation  interpolation_operation
# 0       1.023810          1.023810                 1.023810
# 1       0.971880          0.971880                 0.971880
# 2       1.073446          1.073446                 1.073446
# 4       1.081081          1.081081                 1.081081
# 5       1.103627          1.103627                 1.103627
# ...          ...               ...                      ...
# 20635   1.133333          1.133333                 1.133333
# 20636        NaN          1.048684                 1.126713
# 20637   1.120092          1.120092                 1.120092
# 20638   1.171920          1.171920                 1.171920
# 20639   1.162264          1.162264                 1.162264
#
# [19654 rows x 3 columns]

# %%
data2.describe()
# Out:
#           AveBedrms  median_operation  interpolation_operation
# count  18662.000000      19654.000000             19654.000000
# mean       1.095899          1.093516                 1.096190
# std        0.481693          0.469493                 0.475223
# min        0.333333          0.333333                 0.333333
# 25%        1.006003          1.008444                 1.006593
# 50%        1.048684          1.048684                 1.048632
# 75%        1.098940          1.095454                 1.098499
# max       34.066667         34.066667                34.066667

# %%
interpolated_data = data2[["interpolation_operation"]]

# %%
interpolated_data
# Out:
#        interpolation_operation
# 0                     1.023810
# 1                     0.971880
# 2                     1.073446
# 4                     1.081081
# 5                     1.103627
# ...                        ...
# 20635                 1.133333
# 20636                 1.126713
# 20637                 1.120092
# 20638                 1.171920
# 20639                 1.162264
#
# [19654 rows x 1 columns]

# %%
plt.plot(data2["interpolation_operation"], marker = "o", color = "r", label = "interpolation_operation")
plt.xlabel("Index")
plt.ylabel("Interpolated Values")
plt.title("Line Plot of AveBedrms with Interpolated Values")
plt.legend()
plt.show()

# %%
sns.lineplot(data = interpolated_data, marker = "o")
plt.xlabel("Index")
plt.ylabel("Interpolated Values")
plt.title("Line Plot of AveBedrms with Interpolated Values")
plt.show()

# %% [markdown]
# ## Bonus Question

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic["embark_town"].dropna().shape
# Out:
# (889,)

# %%
titanic = titanic.dropna(subset= ["embark_town"])

# %%
titanic[["deck"]].isnull().sum()
# Out:
# deck    688
# dtype: int64

# %%
Data3 = titanic[["deck"]]

# %%
Data3
# Out:
#     deck
# 0    NaN
# 1      C
# 2    NaN
# 3      C
# 4    NaN
# ..   ...
# 886  NaN
# 887    B
# 888  NaN
# 889    C
# 890  NaN
#
# [889 rows x 1 columns]

# %%
# Deck column has a Categorical data so we can only use ffill, bfill and ffill & bfill combo operation to handle this categorical data

# %%
Data3["ffill_operation"] = Data3["deck"].fillna(method = "ffill")
# Out:
# /var/folders/w8/9lh5cdc953qdl52569vcm35r0000gn/T/ipykernel_5037/1144884747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["ffill_operation"] = Data3["deck"].fillna(method = "ffill")

# %%
Data3["bfill_operation"] = Data3["deck"].fillna(method = "bfill")
# Out:
# /var/folders/w8/9lh5cdc953qdl52569vcm35r0000gn/T/ipykernel_5037/1269933987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["bfill_operation"] = Data3["deck"].fillna(method = "bfill")

# %%
Data3["combo_ffill_bfill_operation"] = Data3["deck"].fillna(method = "bfill")
Data3["combo_ffill_bfill_operation"] = Data3["combo_ffill_bfill_operation"].fillna(method = "ffill")
# Out:
# /var/folders/w8/9lh5cdc953qdl52569vcm35r0000gn/T/ipykernel_5037/1296547578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["combo_ffill_bfill_operation"] = Data3["deck"].fillna(method = "bfill")
# /var/folders/w8/9lh5cdc953qdl52569vcm35r0000gn/T/ipykernel_5037/1296547578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["combo_ffill_bfill_operation"] = Data3["combo_ffill_bfill_operation"].fillna(method = "ffill")

# %%
Data3.describe()
# Out:
#        deck ffill_operation bfill_operation combo_ffill_bfill_operation
# count   201             888             888                         889
# unique    7               7               7                           7
# top       C               C               C                           C
# freq     59             259             254                         255

# %%
Data3
# Out:
#     deck ffill_operation bfill_operation combo_ffill_bfill_operation
# 0    NaN             NaN               C                           C
# 1      C               C               C                           C
# 2    NaN               C               C                           C
# 3      C               C               C                           C
# 4    NaN               C               E                           E
# ..   ...             ...             ...                         ...
# 886  NaN               C               B                           B
# 887    B               B               B                           B
# 888  NaN               B               C                           C
# 889    C               C               C                           C
# 890  NaN               C             NaN                           C
#
# [889 rows x 4 columns]
